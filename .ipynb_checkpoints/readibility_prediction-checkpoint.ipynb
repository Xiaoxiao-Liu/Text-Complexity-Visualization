# %%
import numpy as np  # 引入numpy
import scipy as sp
import pylab as pl
from scipy.optimize import leastsq  # 引入最小二乘函数
from pymysql import *
import pandas as pd
#import color_generatior as cg
import pandas as pd
from sklearn import preprocessing
import time

n = 9  # 多项式次数

# %%
 
# 目标函数
def real_func(x):
    return (2*x)

# %%
 
# 多项式函数
def fit_func(p, x):
    f = np.poly1d(p)
    return f(x)

# %%
 
# 残差函数
def residuals_func(p, y, x):
    ret = fit_func(p, x) - y
    return ret

# %%
 
x = np.linspace(0, 1, 9)  # 随机选择9个点作为x
x_points = np.linspace(0, 1, 1000)  # 画图时需要的连续点
 
y0 = real_func(x)  # 目标函数
y1 = [np.random.normal(0, 0.1) + y for y in y0]  # 添加正太分布噪声后的函数
 
p_init = np.random.randn(n)  # 随机初始化多项式参数
 
plsq = leastsq(residuals_func, p_init, args=(y1, x))
 
print('Fitting Parameters: ', plsq[0] ) # 输出拟合参数
# Out:
# Fitting Parameters:  [-4.66654062e+03  1.87554785e+04 -3.06423939e+04  2.60906086e+04
#  -1.23258584e+04  3.17172000e+03 -4.01668277e+02  2.05840335e+01
#   7.71944007e-03]

# %%
pl.plot(x_points, real_func(x_points), label='real')
pl.plot(x_points, fit_func(plsq[0], x_points), label='fitted curve')
pl.plot(x, y1, 'bo', label='with noise')
pl.legend()
pl.show()

# %%
regularization = 0.1  # 正则化系数lambda
 
# 残差函数
def residuals_func(p, y, x):
    ret = fit_func(p, x) - y
    ret = np.append(ret, np.sqrt(regularization) * p)   # 将lambda^(1/2)p加在了返回的array的后面
    return ret

# %%
def emo_sql_read():
    conn = connect(host='121.40.208.170', port=3306, user='root', password='123456', database='Text_Project')
    # 获得cursor对象
    emo_cursor = conn.cursor()
    #emo_cursor.execute("SHOW COLUMNS FROM text_table")
    emo_cursor.execute("SELECT * FROM text_table t ;")
    #emo_cursor.execute("SELECT DISTINCT w.word, w.property,w.chinese_property, w.importance FROM word_table w ;")
    #emo_cursor.execute("SELECT DISTINCT  w.word, w.property,w.chinese_property, w.importance,w.emotion FROM word_table w join sentence_table s on w.sentence_id=s.sentence_id join(select *from text_table where text_title="+title+") t on s.text_id=t.text_id;")
    story_data = emo_cursor.fetchall()
    return story_data

# %%
columns = ['text_id', 'text_title', 'text_lead', 'readability', 'max', 
           'sixte', 'median', 'quartile', 'min', 'emtion_entropy', 
           'property_entropy', 'importance_entropy', 'strokes_entropy', 'strokes_16_pro', 
           'file']
# Out:
# ['text_id', 'text_title', 'text_lead', 'readability', 'max', 'sixte', 'median', 'quartile', 'min', 'emtion_entropy', 'property_entropy', 'importance_entropy', 'strokes_entropy', 'strokes_16_pro', 'file']

# %%
story_data = emo_sql_read()
story_df = pd.DataFrame(list(story_data),columns = columns)

# %%
print(len(story_data))
# Out:
# 7324

# %%
#story_df.head()
new_stodf = story_df[['readability', 'emtion_entropy','median','strokes_16_pro',
           'property_entropy', 'importance_entropy', 'strokes_entropy']].dropna(axis=0)
#new_stodf.head()
print(len(new_stodf))
# Out:
# 7316

# %%
train = new_stodf[['readability', 'emtion_entropy','median','strokes_16_pro']].iloc[0:5000]
test = new_stodf[['readability', 'emtion_entropy','median','strokes_16_pro']].iloc[5000:7000]

# %%
train.values
# Out:
# array([[6.625e+00, 1.210e-01, 2.140e+02, 1.000e-02],
#        [6.925e+00, 7.000e-02, 4.900e+01, 2.000e-03],
#        [6.988e+00, 2.830e-01, 2.280e+02, 8.000e-03],
#        ...,
#        [6.411e+00, 3.500e-02, 1.565e+02, 5.000e-03],
#        [5.862e+00, 8.700e-02, 3.150e+02, 4.000e-03],
#        [7.098e+00, 9.700e-02, 3.640e+02, 2.000e-02]])

# %%
new_stodf.head()
# Out:
#    readability  emtion_entropy  median  strokes_16_pro  property_entropy  \
# 0        6.625           0.121   214.0           0.010             0.462
# 1        6.925           0.070    49.0           0.002             0.481
# 2        6.988           0.283   228.0           0.008             0.403
# 3        8.158           0.185   113.0           0.001             0.415
# 4        6.778           0.059    42.5           0.010             0.516
#
#    importance_entropy  strokes_entropy
# 0               0.129            0.462
# 1               0.215            0.481
# 2               0.096            0.403
# 3               0.136            0.415
# 4               0.086            0.516

# %%
for i in new_stodf[['readability', 'emtion_entropy','median','strokes_16_pro']].iterrows():
    print(i)
# Out:
# (0, readability         6.625
# emtion_entropy      0.121
# median            214.000
# strokes_16_pro      0.010
# Name: 0, dtype: float64)
# (1, readability        6.925
# emtion_entropy     0.070
# median            49.000
# strokes_16_pro     0.002
# Name: 1, dtype: float64)
# (2, readability         6.988
# emtion_entropy      0.283
# median            228.000
# strokes_16_pro      0.008
# Name: 2, dtype: float64)
# (3, readability         8.158
# emtion_entropy      0.185
# median            113.000
# strokes_16_pro      0.001
# Name: 3, dtype: float64)
# (4, readability        6.778
# emtion_entropy     0.059
# median            42.500
# strokes_16_pro     0.010
# Name: 4, dtype: float64)
# (5, readability        6.849
# emtion_entropy     0.035
# median            29.500
# strokes_16_pro     0.004
# Name: 5, dtype: float64)
# (6, readability        6.308
# emtion_entropy     0.044
# median            34.500
# strokes_16_pro     0.004
# Name: 6, dtype: float64)
# (7, readability        6.656
# emtion_entropy     0.131
# median            97.000
# strokes_16_pro     0.003
# Name: 7, dtype: float64)
# (8, readability         6.621
# emtion_entropy      0.164
# median            111.000
# strokes_16_pro      0.005
# Name: 8, dtype: float64)
# (9, readability        6.355
# emtion_entropy     0.091
# median            98.000
# strokes_16_pro     0.006
# Name: 9, dtype: float64)
# (10, readability        7.476
# emtion_entropy     0.078
# median            44.500
# strokes_16_pro     0.005
# Name: 10, dtype: float64)
# (11, readability         6.496
# emtion_entropy      0.115
# median            100.000
# strokes_16_pro      0.011
# Name: 11, dtype: float64)
# (12, readability         6.162
# emtion_entropy      0.133
# median            116.000
# strokes_16_pro      0.004
# Name: 12, dtype: float64)
# (13, readability         6.641
# emtion_entropy      0.122
# median            105.000
# strokes_16_pro      0.003
# Name: 13, dtype: float64)
# (14, readability        7.025
# emtion_entropy     0.045
# median            45.000
# strokes_16_pro     0.002
# Name: 14, dtype: float64)
# (15, readability         5.974
# emtion_entropy      0.251
# median            243.000
# strokes_16_pro      0.012
# Name: 15, dtype: float64)
# (16, readability         6.786
# emtion_entropy      0.167
# median            114.500
# strokes_16_pro      0.005
# Name: 16, dtype: float64)
# (17, readability         6.743
# emtion_entropy      0.178
# median            109.000
# strokes_16_pro      0.005
# Name: 17, dtype: float64)
# (18, readability         6.526
# emtion_entropy      0.155
# median            122.500
# strokes_16_pro      0.005
# Name: 18, dtype: float64)
# (19, readability        6.546
# emtion_entropy     0.043
# median            38.000
# strokes_16_pro     0.016
# Name: 19, dtype: float64)
# (20, readability        6.994
# emtion_entropy     0.032
# median            48.500
# strokes_16_pro     0.013
# Name: 20, dtype: float64)
# (21, readability         7.066
# emtion_entropy      0.146
# median            135.000
# strokes_16_pro      0.005
# Name: 21, dtype: float64)
# (22, readability         6.294
# emtion_entropy      0.190
# median            389.500
# strokes_16_pro      0.007
# Name: 22, dtype: float64)
# (23, readability         6.801
# emtion_entropy      0.247
# median            252.500
# strokes_16_pro      0.006
# Name: 23, dtype: float64)
# (24, readability        7.234
# emtion_entropy     0.066
# median            91.000
# strokes_16_pro     0.007
# Name: 24, dtype: float64)
# (25, readability        6.059
# emtion_entropy     0.022
# median            38.000
# strokes_16_pro     0.012
# Name: 25, dtype: float64)
# (26, readability        6.733
# emtion_entropy     0.017
# median            35.500
# strokes_16_pro     0.014
# Name: 26, dtype: float64)
# (27, readability         6.357
# emtion_entropy      0.047
# median            104.500
# strokes_16_pro      0.004
# Name: 27, dtype: float64)
# (28, readability         6.985
# emtion_entropy      0.070
# median            121.500
# strokes_16_pro      0.014
# Name: 28, dtype: float64)
# (29, readability         6.870
# emtion_entropy      0.134
# median            225.500
# strokes_16_pro      0.007
# Name: 29, dtype: float64)
# (30, readability         6.994
# emtion_entropy      0.078
# median            109.500
# strokes_16_pro      0.003
# Name: 30, dtype: float64)
# (31, readability        7.322
# emtion_entropy     0.051
# median            74.000
# strokes_16_pro     0.014
# Name: 31, dtype: float64)
# (32, readability        7.049
# emtion_entropy     0.029
# median            81.500
# strokes_16_pro     0.008
# Name: 32, dtype: float64)
# (33, readability         6.392
# emtion_entropy      0.109
# median            205.000
# strokes_16_pro      0.009
# Name: 33, dtype: float64)
# (34, readability         7.814
# emtion_entropy      0.059
# median            107.000
# strokes_16_pro      0.011
# Name: 34, dtype: float64)
# (35, readability         6.661
# emtion_entropy      0.087
# median            197.500
# strokes_16_pro      0.018
# Name: 35, dtype: float64)
# (36, readability         6.537
# emtion_entropy      0.231
# median            511.500
# strokes_16_pro      0.007
# Name: 36, dtype: float64)
# (37, readability        6.944
# emtion_entropy     0.011
# median            46.500
# strokes_16_pro     0.003
# Name: 37, dtype: float64)
# (38, readability        7.922
# emtion_entropy     0.021
# median            51.000
# strokes_16_pro     0.008
# Name: 38, dtype: float64)
# (39, readability         6.324
# emtion_entropy      0.193
# median            362.000
# strokes_16_pro      0.010
# Name: 39, dtype: float64)
# (40, readability         7.415
# emtion_entropy      0.130
# median            237.000
# strokes_16_pro      0.012
# Name: 40, dtype: float64)
# (41, readability        7.094
# emtion_entropy     0.029
# median            53.000
# strokes_16_pro     0.009
# Name: 41, dtype: float64)
# (42, readability         6.345
# emtion_entropy      0.048
# median            109.000
# strokes_16_pro      0.010
# Name: 42, dtype: float64)
# (43, readability        6.802
# emtion_entropy     0.012
# median            32.000
# strokes_16_pro     0.003
# Name: 43, dtype: float64)
# (44, readability        6.695
# emtion_entropy     0.007
# median            20.000
# strokes_16_pro     0.003
# Name: 44, dtype: float64)
# (45, readability        7.052
# emtion_entropy     0.007
# median            17.500
# strokes_16_pro     0.014
# Name: 45, dtype: float64)
# (46, readability        8.940
# emtion_entropy     0.009
# median            16.000
# strokes_16_pro     0.015
# Name: 46, dtype: float64)
# (47, readability        7.319
# emtion_entropy     0.031
# median            51.000
# strokes_16_pro     0.011
# Name: 47, dtype: float64)
# (48, readability        6.429
# emtion_entropy     0.048
# median            94.000
# strokes_16_pro     0.008
# Name: 48, dtype: float64)
# (49, readability        6.489
# emtion_entropy     0.026
# median            53.500
# strokes_16_pro     0.009
# Name: 49, dtype: float64)
# (50, readability         6.392
# emtion_entropy      0.248
# median            537.000
# strokes_16_pro      0.015
# Name: 50, dtype: float64)
# (51, readability         7.485
# emtion_entropy      0.092
# median            207.000
# strokes_16_pro      0.010
# Name: 51, dtype: float64)
# (52, readability         7.017
# emtion_entropy      0.070
# median            104.000
# strokes_16_pro      0.004
# Name: 52, dtype: float64)
# (53, readability        7.348
# emtion_entropy     0.059
# median            72.000
# strokes_16_pro     0.003
# Name: 53, dtype: float64)
# (54, readability        6.807
# emtion_entropy     0.042
# median            90.000
# strokes_16_pro     0.006
# Name: 54, dtype: float64)
# (55, readability         6.749
# emtion_entropy      0.177
# median            211.500
# strokes_16_pro      0.008
# Name: 55, dtype: float64)
# (56, readability         7.551
# emtion_entropy      0.039
# median            113.000
# strokes_16_pro      0.012
# Name: 56, dtype: float64)
# (57, readability        6.178
# emtion_entropy     0.035
# median            50.500
# strokes_16_pro     0.009
# Name: 57, dtype: float64)
# (58, readability         6.739
# emtion_entropy      0.121
# median            174.500
# strokes_16_pro      0.005
# Name: 58, dtype: float64)
# (59, readability         6.146
# emtion_entropy      0.109
# median            178.500
# strokes_16_pro      0.010
# Name: 59, dtype: float64)
# (60, readability         7.094
# emtion_entropy      0.184
# median            285.500
# strokes_16_pro      0.006
# Name: 60, dtype: float64)
# (61, readability         6.572
# emtion_entropy      0.154
# median            307.000
# strokes_16_pro      0.010
# Name: 61, dtype: float64)
# (62, readability         7.251
# emtion_entropy      0.491
# median            782.500
# strokes_16_pro      0.007
# Name: 62, dtype: float64)
# (63, readability         7.340
# emtion_entropy      0.177
# median            468.000
# strokes_16_pro      0.016
# Name: 63, dtype: float64)
# (64, readability         6.089
# emtion_entropy      0.306
# median            590.000
# strokes_16_pro      0.008
# Name: 64, dtype: float64)
# (65, readability          6.883
# emtion_entropy       0.595
# median            1016.000
# strokes_16_pro       0.010
# Name: 65, dtype: float64)
# (66, readability         6.752
# emtion_entropy      0.077
# median            170.000
# strokes_16_pro      0.008
# Name: 66, dtype: float64)
# (67, readability         7.190
# emtion_entropy      0.442
# median            806.000
# strokes_16_pro      0.010
# Name: 67, dtype: float64)
# (68, readability         6.797
# emtion_entropy      0.498
# median            987.000
# strokes_16_pro      0.008
# Name: 68, dtype: float64)
# (69, readability         6.460
# emtion_entropy      0.168
# median            391.500
# strokes_16_pro      0.007
# Name: 69, dtype: float64)
# (70, readability         6.461
# emtion_entropy      0.410
# median            990.000
# strokes_16_pro      0.009
# Name: 70, dtype: float64)
# (71, readability          6.812
# emtion_entropy       0.577
# median            1046.000
# strokes_16_pro       0.010
# Name: 71, dtype: float64)
# (72, readability         7.492
# emtion_entropy      0.672
# median            910.500
# strokes_16_pro      0.008
# Name: 72, dtype: float64)
# (73, readability        6.908
# emtion_entropy     0.025
# median            76.000
# strokes_16_pro     0.007
# Name: 73, dtype: float64)
# (74, readability        6.856
# emtion_entropy     0.025
# median            28.000
# strokes_16_pro     0.006
# Name: 74, dtype: float64)
# (75, readability         6.265
# emtion_entropy      0.284
# median            575.500
# strokes_16_pro      0.009
# Name: 75, dtype: float64)
# (76, readability         6.454
# emtion_entropy      0.333
# median            753.500
# strokes_16_pro      0.013
# Name: 76, dtype: float64)
# (77, readability         6.660
# emtion_entropy      0.081
# median            145.500
# strokes_16_pro      0.008
# Name: 77, dtype: float64)
# (78, readability         7.000
# emtion_entropy      0.105
# median            297.000
# strokes_16_pro      0.007
# Name: 78, dtype: float64)
# (79, readability         6.715
# emtion_entropy      0.098
# median            165.500
# strokes_16_pro      0.006
# Name: 79, dtype: float64)
# (80, readability          6.141
# emtion_entropy       0.543
# median            1289.000
# strokes_16_pro       0.008
# Name: 80, dtype: float64)
# (81, readability         6.817
# emtion_entropy      0.216
# median            359.000
# strokes_16_pro      0.018
# Name: 81, dtype: float64)
# (82, readability         6.567
# emtion_entropy      0.079
# median            128.500
# strokes_16_pro      0.004
# Name: 82, dtype: float64)
# (83, readability         6.408
# emtion_entropy      0.083
# median            115.000
# strokes_16_pro      0.004
# Name: 83, dtype: float64)
# (84, readability         6.993
# emtion_entropy      0.145
# median            226.000
# strokes_16_pro      0.006
# Name: 84, dtype: float64)
# (85, readability         6.848
# emtion_entropy      0.419
# median            798.500
# strokes_16_pro      0.006
# Name: 85, dtype: float64)
# (86, readability         6.261
# emtion_entropy      0.116
# median            193.500
# strokes_16_pro      0.007
# Name: 86, dtype: float64)
# (87, readability         6.974
# emtion_entropy      0.074
# median            165.500
# strokes_16_pro      0.006
# Name: 87, dtype: float64)
# (88, readability         6.774
# emtion_entropy      0.197
# median            395.500
# strokes_16_pro      0.004
# Name: 88, dtype: float64)
# (89, readability         7.200
# emtion_entropy      0.104
# median            168.000
# strokes_16_pro      0.006
# Name: 89, dtype: float64)
# (90, readability         6.324
# emtion_entropy      0.065
# median            134.500
# strokes_16_pro      0.005
# Name: 90, dtype: float64)
# (91, readability         6.853
# emtion_entropy      0.080
# median            212.500
# strokes_16_pro      0.009
# Name: 91, dtype: float64)
# (92, readability         5.660
# emtion_entropy      0.074
# median            196.500
# strokes_16_pro      0.020
# Name: 92, dtype: float64)
# (93, readability        7.155
# emtion_entropy     0.024
# median            60.000
# strokes_16_pro     0.019
# Name: 93, dtype: float64)
# (94, readability        7.619
# emtion_entropy     0.017
# median            46.000
# strokes_16_pro     0.009
# Name: 94, dtype: float64)
# (95, readability        7.103
# emtion_entropy     0.018
# median            27.500
# strokes_16_pro     0.008
# Name: 95, dtype: float64)
# (96, readability        7.583
# emtion_entropy     0.021
# median            47.000
# strokes_16_pro     0.004
# Name: 96, dtype: float64)
# (97, readability         6.446
# emtion_entropy      0.343
# median            570.500
# strokes_16_pro      0.009
# Name: 97, dtype: float64)
# (98, readability        6.944
# emtion_entropy     0.002
# median            15.000
# strokes_16_pro     0.000
# Name: 98, dtype: float64)
# (99, readability        7.494
# emtion_entropy     0.017
# median            44.500
# strokes_16_pro     0.017
# Name: 99, dtype: float64)
# (100, readability         6.765
# emtion_entropy      0.098
# median            172.500
# strokes_16_pro      0.005
# Name: 100, dtype: float64)
# (101, readability        7.573
# emtion_entropy     0.041
# median            82.000
# strokes_16_pro     0.010
# Name: 101, dtype: float64)
# (102, readability         6.781
# emtion_entropy      0.056
# median            128.500
# strokes_16_pro      0.006
# Name: 102, dtype: float64)
# (103, readability        6.196
# emtion_entropy     0.036
# median            57.000
# strokes_16_pro     0.012
# Name: 103, dtype: float64)
# (104, readability        6.318
# emtion_entropy     0.029
# median            61.500
# strokes_16_pro     0.003
# Name: 104, dtype: float64)
# (105, readability         7.064
# emtion_entropy      0.056
# median            130.500
# strokes_16_pro      0.018
# Name: 105, dtype: float64)
# (106, readability         5.868
# emtion_entropy      0.088
# median            211.000
# strokes_16_pro      0.019
# Name: 106, dtype: float64)
# (107, readability        6.567
# emtion_entropy     0.039
# median            86.500
# strokes_16_pro     0.026
# Name: 107, dtype: float64)
# (108, readability        6.991
# emtion_entropy     0.030
# median            76.500
# strokes_16_pro     0.004
# Name: 108, dtype: float64)
# (109, readability         7.000
# emtion_entropy      0.052
# median            143.000
# strokes_16_pro      0.023
# Name: 109, dtype: float64)
# (110, readability        7.189
# emtion_entropy     0.033
# median            64.000
# strokes_16_pro     0.003
# Name: 110, dtype: float64)
# (111, readability         6.989
# emtion_entropy      0.097
# median            166.500
# strokes_16_pro      0.016
# Name: 111, dtype: float64)
# (112, readability          6.398
# emtion_entropy       0.539
# median            1112.000
# strokes_16_pro       0.010
# Name: 112, dtype: float64)
# (113, readability        6.697
# emtion_entropy     0.026
# median            39.500
# strokes_16_pro     0.003
# Name: 113, dtype: float64)
# (114, readability        6.622
# emtion_entropy     0.055
# median            69.500
# strokes_16_pro     0.008
# Name: 114, dtype: float64)
# (115, readability         6.527
# emtion_entropy      0.242
# median            537.500
# strokes_16_pro      0.015
# Name: 115, dtype: float64)
# (116, readability        7.097
# emtion_entropy     0.044
# median            79.500
# strokes_16_pro     0.005
# Name: 116, dtype: float64)
# (117, readability         7.150
# emtion_entropy      0.094
# median            126.500
# strokes_16_pro      0.005
# Name: 117, dtype: float64)
# (118, readability         7.157
# emtion_entropy      0.061
# median            129.000
# strokes_16_pro      0.012
# Name: 118, dtype: float64)
# (119, readability        6.494
# emtion_entropy     0.026
# median            55.000
# strokes_16_pro     0.007
# Name: 119, dtype: float64)
# (120, readability        7.137
# emtion_entropy     0.045
# median            83.000
# strokes_16_pro     0.010
# Name: 120, dtype: float64)
# (121, readability         6.687
# emtion_entropy      0.224
# median            512.500
# strokes_16_pro      0.014
# Name: 121, dtype: float64)
# (122, readability        7.456
# emtion_entropy     0.014
# median            31.000
# strokes_16_pro     0.004
# Name: 122, dtype: float64)
# (123, readability         6.507
# emtion_entropy      0.084
# median            238.000
# strokes_16_pro      0.009
# Name: 123, dtype: float64)
# (124, readability        6.061
# emtion_entropy     0.035
# median            86.500
# strokes_16_pro     0.011
# Name: 124, dtype: float64)
# (125, readability        7.186
# emtion_entropy     0.006
# median            27.000
# strokes_16_pro     0.000
# Name: 125, dtype: float64)
# (126, readability        7.793
# emtion_entropy     0.014
# median            26.500
# strokes_16_pro     0.002
# Name: 126, dtype: float64)
# (127, readability         6.524
# emtion_entropy      0.056
# median            135.000
# strokes_16_pro      0.006
# Name: 127, dtype: float64)
# (128, readability        5.723
# emtion_entropy     0.027
# median            66.500
# strokes_16_pro     0.003
# Name: 128, dtype: float64)
# (129, readability         6.078
# emtion_entropy      0.065
# median            133.500
# strokes_16_pro      0.006
# Name: 129, dtype: float64)
# (130, readability         6.775
# emtion_entropy      0.076
# median            146.500
# strokes_16_pro      0.011
# Name: 130, dtype: float64)
# (131, readability        6.968
# emtion_entropy     0.020
# median            52.500
# strokes_16_pro     0.003
# Name: 131, dtype: float64)
# (132, readability         6.809
# emtion_entropy      0.042
# median            115.500
# strokes_16_pro      0.005
# Name: 132, dtype: float64)
# (133, readability         7.045
# emtion_entropy      0.062
# median            135.000
# strokes_16_pro      0.006
# Name: 133, dtype: float64)
# (134, readability        6.704
# emtion_entropy     0.037
# median            78.500
# strokes_16_pro     0.015
# Name: 134, dtype: float64)
# (135, readability         6.795
# emtion_entropy      0.080
# median            135.000
# strokes_16_pro      0.022
# Name: 135, dtype: float64)
# (136, readability         7.353
# emtion_entropy      0.052
# median            119.000
# strokes_16_pro      0.011
# Name: 136, dtype: float64)
# (137, readability        5.918
# emtion_entropy     0.034
# median            63.500
# strokes_16_pro     0.003
# Name: 137, dtype: float64)
# (138, readability         6.621
# emtion_entropy      0.350
# median            626.000
# strokes_16_pro      0.011
# Name: 138, dtype: float64)
# (139, readability        6.697
# emtion_entropy     0.050
# median            90.500
# strokes_16_pro     0.003
# Name: 139, dtype: float64)
# (140, readability         6.755
# emtion_entropy      0.061
# median            121.000
# strokes_16_pro      0.007
# Name: 140, dtype: float64)
# (141, readability        6.550
# emtion_entropy     0.016
# median            31.000
# strokes_16_pro     0.008
# Name: 141, dtype: float64)
# (142, readability         7.307
# emtion_entropy      0.121
# median            235.000
# strokes_16_pro      0.006
# Name: 142, dtype: float64)
# (143, readability        7.017
# emtion_entropy     0.023
# median            48.000
# strokes_16_pro     0.015
# Name: 143, dtype: float64)
# (144, readability         6.899
# emtion_entropy      0.037
# median            127.500
# strokes_16_pro      0.008
# Name: 144, dtype: float64)
# (145, readability         7.279
# emtion_entropy      0.106
# median            167.000
# strokes_16_pro      0.011
# Name: 145, dtype: float64)
# (146, readability        6.802
# emtion_entropy     0.036
# median            56.500
# strokes_16_pro     0.006
# Name: 146, dtype: float64)
# (147, readability        6.568
# emtion_entropy     0.018
# median            45.000
# strokes_16_pro     0.012
# Name: 147, dtype: float64)
# (148, readability         7.335
# emtion_entropy      0.089
# median            119.500
# strokes_16_pro      0.010
# Name: 148, dtype: float64)
# (149, readability        6.716
# emtion_entropy     0.041
# median            90.000
# strokes_16_pro     0.012
# Name: 149, dtype: float64)
# (150, readability        6.677
# emtion_entropy     0.063
# median            70.500
# strokes_16_pro     0.004
# Name: 150, dtype: float64)
# (151, readability         6.446
# emtion_entropy      0.074
# median            106.500
# strokes_16_pro      0.004
# Name: 151, dtype: float64)
# (152, readability         6.699
# emtion_entropy      0.097
# median            175.500
# strokes_16_pro      0.012
# Name: 152, dtype: float64)
# (153, readability        7.541
# emtion_entropy     0.033
# median            38.500
# strokes_16_pro     0.003
# Name: 153, dtype: float64)
# (154, readability        6.625
# emtion_entropy     0.047
# median            57.500
# strokes_16_pro     0.002
# Name: 154, dtype: float64)
# (155, readability        8.036
# emtion_entropy     0.022
# median            30.000
# strokes_16_pro     0.016
# Name: 155, dtype: float64)
# (156, readability         6.780
# emtion_entropy      0.135
# median            197.000
# strokes_16_pro      0.004
# Name: 156, dtype: float64)
# (157, readability         7.526
# emtion_entropy      0.095
# median            135.500
# strokes_16_pro      0.003
# Name: 157, dtype: float64)
# (158, readability         6.865
# emtion_entropy      0.173
# median            143.000
# strokes_16_pro      0.007
# Name: 158, dtype: float64)
# (159, readability         7.555
# emtion_entropy      0.102
# median            121.500
# strokes_16_pro      0.007
# Name: 159, dtype: float64)
# (160, readability         7.698
# emtion_entropy      0.162
# median            135.500
# strokes_16_pro      0.007
# Name: 160, dtype: float64)
# (161, readability        6.495
# emtion_entropy     0.050
# median            59.500
# strokes_16_pro     0.006
# Name: 161, dtype: float64)
# (162, readability         7.302
# emtion_entropy      0.065
# median            106.500
# strokes_16_pro      0.006
# Name: 162, dtype: float64)
# (163, readability         6.650
# emtion_entropy      0.078
# median            134.500
# strokes_16_pro      0.005
# Name: 163, dtype: float64)
# (164, readability         6.343
# emtion_entropy      0.124
# median            158.000
# strokes_16_pro      0.009
# Name: 164, dtype: float64)
# (165, readability         6.787
# emtion_entropy      0.060
# median            141.000
# strokes_16_pro      0.006
# Name: 165, dtype: float64)
# (166, readability         7.268
# emtion_entropy      0.277
# median            386.000
# strokes_16_pro      0.004
# Name: 166, dtype: float64)
# (167, readability         7.014
# emtion_entropy      0.174
# median            241.500
# strokes_16_pro      0.005
# Name: 167, dtype: float64)
# (168, readability         6.737
# emtion_entropy      0.233
# median            636.500
# strokes_16_pro      0.019
# Name: 168, dtype: float64)
# (169, readability        7.161
# emtion_entropy     0.060
# median            70.000
# strokes_16_pro     0.002
# Name: 169, dtype: float64)
# (170, readability         6.973
# emtion_entropy      0.085
# median            116.000
# strokes_16_pro      0.005
# Name: 170, dtype: float64)
# (171, readability         6.343
# emtion_entropy      0.146
# median            158.000
# strokes_16_pro      0.005
# Name: 171, dtype: float64)
# (172, readability        6.674
# emtion_entropy     0.055
# median            65.000
# strokes_16_pro     0.008
# Name: 172, dtype: float64)
# (173, readability         6.861
# emtion_entropy      0.078
# median            105.500
# strokes_16_pro      0.009
# Name: 173, dtype: float64)
# (174, readability        6.390
# emtion_entropy     0.060
# median            89.000
# strokes_16_pro     0.006
# Name: 174, dtype: float64)
# (175, readability        6.682
# emtion_entropy     0.088
# median            88.500
# strokes_16_pro     0.015
# Name: 175, dtype: float64)
# (176, readability         6.163
# emtion_entropy      0.100
# median            146.500
# strokes_16_pro      0.008
# Name: 176, dtype: float64)
# (177, readability         6.414
# emtion_entropy      0.101
# median            126.500
# strokes_16_pro      0.012
# Name: 177, dtype: float64)
# (178, readability         6.077
# emtion_entropy      0.121
# median            189.000
# strokes_16_pro      0.004
# Name: 178, dtype: float64)
# (179, readability        6.571
# emtion_entropy     0.026
# median            37.500
# strokes_16_pro     0.007
# Name: 179, dtype: float64)
# (180, readability        6.824
# emtion_entropy     0.049
# median            53.500
# strokes_16_pro     0.004
# Name: 180, dtype: float64)
# (181, readability         7.025
# emtion_entropy      0.043
# median            103.000
# strokes_16_pro      0.013
# Name: 181, dtype: float64)
# (182, readability         6.580
# emtion_entropy      0.146
# median            145.500
# strokes_16_pro      0.011
# Name: 182, dtype: float64)
# (183, readability         7.165
# emtion_entropy      0.252
# median            343.500
# strokes_16_pro      0.008
# Name: 183, dtype: float64)
# (184, readability         6.268
# emtion_entropy      0.208
# median            486.500
# strokes_16_pro      0.010
# Name: 184, dtype: float64)
# (185, readability         6.550
# emtion_entropy      0.501
# median            600.000
# strokes_16_pro      0.010
# Name: 185, dtype: float64)
# (186, readability         7.159
# emtion_entropy      0.540
# median            950.500
# strokes_16_pro      0.008
# Name: 186, dtype: float64)
# (187, readability         7.049
# emtion_entropy      0.083
# median            136.000
# strokes_16_pro      0.011
# Name: 187, dtype: float64)
# (188, readability         6.643
# emtion_entropy      0.251
# median            571.000
# strokes_16_pro      0.014
# Name: 188, dtype: float64)
# (189, readability        5.664
# emtion_entropy     0.047
# median            59.500
# strokes_16_pro     0.017
# Name: 189, dtype: float64)
# (190, readability         6.429
# emtion_entropy      0.260
# median            582.000
# strokes_16_pro      0.007
# Name: 190, dtype: float64)
# (191, readability         6.069
# emtion_entropy      0.334
# median            642.500
# strokes_16_pro      0.012
# Name: 191, dtype: float64)
# (192, readability         6.939
# emtion_entropy      0.475
# median            857.000
# strokes_16_pro      0.008
# Name: 192, dtype: float64)
# (193, readability          8.044
# emtion_entropy       0.624
# median            1299.000
# strokes_16_pro       0.021
# Name: 193, dtype: float64)
# (194, readability        7.065
# emtion_entropy     0.054
# median            75.000
# strokes_16_pro     0.006
# Name: 194, dtype: float64)
# (195, readability        6.832
# emtion_entropy     0.024
# median            35.500
# strokes_16_pro     0.023
# Name: 195, dtype: float64)
# (196, readability        6.626
# emtion_entropy     0.034
# median            50.500
# strokes_16_pro     0.017
# Name: 196, dtype: float64)
# (197, readability         6.610
# emtion_entropy      0.069
# median            116.500
# strokes_16_pro      0.009
# Name: 197, dtype: float64)
# (198, readability         7.323
# emtion_entropy      0.168
# median            351.500
# strokes_16_pro      0.016
# Name: 198, dtype: float64)
# (199, readability          7.155
# emtion_entropy       0.843
# median            1506.500
# strokes_16_pro       0.011
# Name: 199, dtype: float64)
# (200, readability         6.912
# emtion_entropy      0.400
# median            929.500
# strokes_16_pro      0.010
# Name: 200, dtype: float64)
# (201, readability         6.764
# emtion_entropy      0.471
# median            969.000
# strokes_16_pro      0.009
# Name: 201, dtype: float64)
# (202, readability         6.859
# emtion_entropy      0.473
# median            895.500
# strokes_16_pro      0.008
# Name: 202, dtype: float64)
# (203, readability         7.124
# emtion_entropy      0.217
# median            363.500
# strokes_16_pro      0.009
# Name: 203, dtype: float64)
# (204, readability         6.785
# emtion_entropy      0.219
# median            456.000
# strokes_16_pro      0.007
# Name: 204, dtype: float64)
# (205, readability         7.035
# emtion_entropy      0.465
# median            680.000
# strokes_16_pro      0.009
# Name: 205, dtype: float64)
# (206, readability         7.155
# emtion_entropy      0.469
# median            666.500
# strokes_16_pro      0.010
# Name: 206, dtype: float64)
# (207, readability          6.751
# emtion_entropy       0.587
# median            1040.500
# strokes_16_pro       0.005
# Name: 207, dtype: float64)
# (208, readability        5.966
# emtion_entropy     0.026
# median            69.000
# strokes_16_pro     0.007
# Name: 208, dtype: float64)
# (209, readability         7.278
# emtion_entropy      0.179
# median            250.000
# strokes_16_pro      0.006
# Name: 209, dtype: float64)
# (210, readability         6.378
# emtion_entropy      0.156
# median            299.500
# strokes_16_pro      0.007
# Name: 210, dtype: float64)
# (211, readability         6.961
# emtion_entropy      0.237
# median            295.000
# strokes_16_pro      0.009
# Name: 211, dtype: float64)
# (212, readability         6.860
# emtion_entropy      0.279
# median            459.000
# strokes_16_pro      0.006
# Name: 212, dtype: float64)
# (213, readability         6.471
# emtion_entropy      0.432
# median            788.500
# strokes_16_pro      0.011
# Name: 213, dtype: float64)
# (214, readability          7.013
# emtion_entropy       0.561
# median            1014.500
# strokes_16_pro       0.006
# Name: 214, dtype: float64)
# (215, readability          6.917
# emtion_entropy       0.657
# median            1038.500
# strokes_16_pro       0.008
# Name: 215, dtype: float64)
# (216, readability         6.861
# emtion_entropy      0.086
# median            140.500
# strokes_16_pro      0.014
# Name: 216, dtype: float64)
# (217, readability        7.732
# emtion_entropy     0.046
# median            89.500
# strokes_16_pro     0.014
# Name: 217, dtype: float64)
# (218, readability         6.665
# emtion_entropy      0.067
# median            145.000
# strokes_16_pro      0.011
# Name: 218, dtype: float64)
# (219, readability         7.632
# emtion_entropy      0.047
# median            108.000
# strokes_16_pro      0.004
# Name: 219, dtype: float64)
# (220, readability         7.034
# emtion_entropy      0.147
# median            220.500
# strokes_16_pro      0.003
# Name: 220, dtype: float64)
# (221, readability         6.678
# emtion_entropy      0.052
# median            121.000
# strokes_16_pro      0.012
# Name: 221, dtype: float64)
# (222, readability         6.756
# emtion_entropy      0.123
# median            201.000
# strokes_16_pro      0.010
# Name: 222, dtype: float64)
# (223, readability         6.007
# emtion_entropy      0.084
# median            179.500
# strokes_16_pro      0.011
# Name: 223, dtype: float64)
# (224, readability         6.722
# emtion_entropy      0.395
# median            688.000
# strokes_16_pro      0.008
# Name: 224, dtype: float64)
# (225, readability         5.708
# emtion_entropy      0.116
# median            310.000
# strokes_16_pro      0.010
# Name: 225, dtype: float64)
# (226, readability         6.379
# emtion_entropy      0.119
# median            324.000
# strokes_16_pro      0.008
# Name: 226, dtype: float64)
# (227, readability         5.968
# emtion_entropy      0.063
# median            181.000
# strokes_16_pro      0.011
# Name: 227, dtype: float64)
# (228, readability         6.936
# emtion_entropy      0.264
# median            462.500
# strokes_16_pro      0.007
# Name: 228, dtype: float64)
# (229, readability         6.963
# emtion_entropy      0.269
# median            500.500
# strokes_16_pro      0.008
# Name: 229, dtype: float64)
# (230, readability         6.919
# emtion_entropy      0.288
# median            520.500
# strokes_16_pro      0.007
# Name: 230, dtype: float64)
# (231, readability        5.664
# emtion_entropy     0.047
# median            59.500
# strokes_16_pro     0.017
# Name: 231, dtype: float64)
# (233, readability         7.565
# emtion_entropy      0.425
# median            569.500
# strokes_16_pro      0.012
# Name: 233, dtype: float64)
# (234, readability          6.790
# emtion_entropy       1.000
# median            2058.500
# strokes_16_pro       0.009
# Name: 234, dtype: float64)
# (235, readability          7.373
# emtion_entropy       0.644
# median            1217.500
# strokes_16_pro       0.008
# Name: 235, dtype: float64)
# (236, readability         6.891
# emtion_entropy      0.413
# median            971.500
# strokes_16_pro      0.009
# Name: 236, dtype: float64)
# (237, readability        7.556
# emtion_entropy     0.015
# median            24.000
# strokes_16_pro     0.000
# Name: 237, dtype: float64)
# (238, readability        7.274
# emtion_entropy     0.010
# median            33.000
# strokes_16_pro     0.021
# Name: 238, dtype: float64)
# (239, readability        6.888
# emtion_entropy     0.010
# median            18.000
# strokes_16_pro     0.024
# Name: 239, dtype: float64)
# (240, readability        7.256
# emtion_entropy     0.024
# median            39.000
# strokes_16_pro     0.007
# Name: 240, dtype: float64)
# (241, readability       10.128
# emtion_entropy     0.012
# median            27.000
# strokes_16_pro     0.001
# Name: 241, dtype: float64)
# (242, readability        6.893
# emtion_entropy     0.017
# median            47.500
# strokes_16_pro     0.004
# Name: 242, dtype: float64)
# (243, readability        8.280
# emtion_entropy     0.010
# median            13.000
# strokes_16_pro     0.003
# Name: 243, dtype: float64)
# (244, readability        7.930
# emtion_entropy     0.029
# median            32.000
# strokes_16_pro     0.000
# Name: 244, dtype: float64)
# (245, readability        7.931
# emtion_entropy     0.008
# median            26.000
# strokes_16_pro     0.006
# Name: 245, dtype: float64)
# (246, readability        8.186
# emtion_entropy     0.013
# median            30.000
# strokes_16_pro     0.013
# Name: 246, dtype: float64)
# (247, readability        8.870
# emtion_entropy     0.019
# median            26.500
# strokes_16_pro     0.015
# Name: 247, dtype: float64)
# (248, readability        6.868
# emtion_entropy     0.022
# median            48.500
# strokes_16_pro     0.007
# Name: 248, dtype: float64)
# (249, readability        7.787
# emtion_entropy     0.019
# median            38.000
# strokes_16_pro     0.007
# Name: 249, dtype: float64)
# (250, readability        7.962
# emtion_entropy     0.011
# median            27.000
# strokes_16_pro     0.006
# Name: 250, dtype: float64)
# (251, readability        8.066
# emtion_entropy     0.020
# median            27.500
# strokes_16_pro     0.032
# Name: 251, dtype: float64)
# (252, readability        6.847
# emtion_entropy     0.008
# median            33.500
# strokes_16_pro     0.007
# Name: 252, dtype: float64)
# (253, readability        7.394
# emtion_entropy     0.020
# median            35.000
# strokes_16_pro     0.011
# Name: 253, dtype: float64)
# (254, readability        7.075
# emtion_entropy     0.018
# median            37.500
# strokes_16_pro     0.009
# Name: 254, dtype: float64)
# (255, readability        7.095
# emtion_entropy     0.016
# median            31.000
# strokes_16_pro     0.003
# Name: 255, dtype: float64)
# (256, readability        6.961
# emtion_entropy     0.012
# median            33.000
# strokes_16_pro     0.002
# Name: 256, dtype: float64)
# (257, readability        7.640
# emtion_entropy     0.032
# median            37.000
# strokes_16_pro     0.003
# Name: 257, dtype: float64)
# (258, readability        8.090
# emtion_entropy     0.008
# median            16.500
# strokes_16_pro     0.010
# Name: 258, dtype: float64)
# (259, readability        7.198
# emtion_entropy     0.013
# median            31.000
# strokes_16_pro     0.007
# Name: 259, dtype: float64)
# (260, readability        7.221
# emtion_entropy     0.012
# median            34.500
# strokes_16_pro     0.002
# Name: 260, dtype: float64)
# (261, readability        6.810
# emtion_entropy     0.011
# median            12.500
# strokes_16_pro     0.010
# Name: 261, dtype: float64)
# (262, readability        6.161
# emtion_entropy     0.007
# median            21.500
# strokes_16_pro     0.013
# Name: 262, dtype: float64)
# (263, readability        7.767
# emtion_entropy     0.010
# median            23.500
# strokes_16_pro     0.004
# Name: 263, dtype: float64)
# (264, readability        6.613
# emtion_entropy     0.016
# median            27.000
# strokes_16_pro     0.010
# Name: 264, dtype: float64)
# (265, readability        7.014
# emtion_entropy     0.019
# median            38.500
# strokes_16_pro     0.002
# Name: 265, dtype: float64)
# (266, readability        6.186
# emtion_entropy     0.017
# median            30.500
# strokes_16_pro     0.009
# Name: 266, dtype: float64)
# (267, readability        7.420
# emtion_entropy     0.014
# median            23.000
# strokes_16_pro     0.012
# Name: 267, dtype: float64)
# (268, readability        6.231
# emtion_entropy     0.021
# median            40.500
# strokes_16_pro     0.003
# Name: 268, dtype: float64)
# (269, readability        7.317
# emtion_entropy     0.023
# median            41.000
# strokes_16_pro     0.011
# Name: 269, dtype: float64)
# (270, readability        9.807
# emtion_entropy     0.017
# median            20.500
# strokes_16_pro     0.002
# Name: 270, dtype: float64)
# (271, readability        7.288
# emtion_entropy     0.008
# median            23.500
# strokes_16_pro     0.005
# Name: 271, dtype: float64)
# (272, readability        7.491
# emtion_entropy     0.022
# median            36.500
# strokes_16_pro     0.031
# Name: 272, dtype: float64)
# (273, readability        6.780
# emtion_entropy     0.010
# median            26.500
# strokes_16_pro     0.011
# Name: 273, dtype: float64)
# (274, readability        6.502
# emtion_entropy     0.009
# median            25.000
# strokes_16_pro     0.008
# Name: 274, dtype: float64)
# (275, readability        8.102
# emtion_entropy     0.011
# median            33.000
# strokes_16_pro     0.003
# Name: 275, dtype: float64)
# (276, readability        6.865
# emtion_entropy     0.019
# median            23.000
# strokes_16_pro     0.011
# Name: 276, dtype: float64)
# (277, readability        8.046
# emtion_entropy     0.009
# median            27.500
# strokes_16_pro     0.011
# Name: 277, dtype: float64)
# (278, readability        6.019
# emtion_entropy     0.011
# median            54.000
# strokes_16_pro     0.005
# Name: 278, dtype: float64)
# (279, readability        8.006
# emtion_entropy     0.012
# median            22.500
# strokes_16_pro     0.013
# Name: 279, dtype: float64)
# (280, readability        7.751
# emtion_entropy     0.030
# median            35.500
# strokes_16_pro     0.011
# Name: 280, dtype: float64)
# (281, readability        7.251
# emtion_entropy     0.033
# median            50.500
# strokes_16_pro     0.005
# Name: 281, dtype: float64)
# (282, readability        9.585
# emtion_entropy     0.006
# median            25.500
# strokes_16_pro     0.006
# Name: 282, dtype: float64)
# (283, readability        7.028
# emtion_entropy     0.016
# median            28.500
# strokes_16_pro     0.010
# Name: 283, dtype: float64)
# (284, readability        8.578
# emtion_entropy     0.026
# median            29.500
# strokes_16_pro     0.005
# Name: 284, dtype: float64)
# (285, readability        6.969
# emtion_entropy     0.012
# median            23.000
# strokes_16_pro     0.003
# Name: 285, dtype: float64)
# (286, readability        6.790
# emtion_entropy     0.020
# median            18.000
# strokes_16_pro     0.003
# Name: 286, dtype: float64)
# (287, readability        8.301
# emtion_entropy     0.027
# median            27.000
# strokes_16_pro     0.006
# Name: 287, dtype: float64)
# (288, readability        9.812
# emtion_entropy     0.013
# median            30.000
# strokes_16_pro     0.035
# Name: 288, dtype: float64)
# (289, readability        6.273
# emtion_entropy     0.015
# median            26.500
# strokes_16_pro     0.017
# Name: 289, dtype: float64)
# (290, readability        9.581
# emtion_entropy     0.019
# median            29.500
# strokes_16_pro     0.004
# Name: 290, dtype: float64)
# (291, readability        7.973
# emtion_entropy     0.013
# median            21.500
# strokes_16_pro     0.035
# Name: 291, dtype: float64)
# (292, readability        7.301
# emtion_entropy     0.025
# median            40.000
# strokes_16_pro     0.003
# Name: 292, dtype: float64)
# (293, readability        7.845
# emtion_entropy     0.010
# median            26.000
# strokes_16_pro     0.008
# Name: 293, dtype: float64)
# (294, readability        8.762
# emtion_entropy     0.029
# median            42.500
# strokes_16_pro     0.025
# Name: 294, dtype: float64)
# (295, readability        7.407
# emtion_entropy     0.005
# median            19.000
# strokes_16_pro     0.003
# Name: 295, dtype: float64)
# (296, readability        9.331
# emtion_entropy     0.024
# median            14.000
# strokes_16_pro     0.010
# Name: 296, dtype: float64)
# (297, readability        8.137
# emtion_entropy     0.009
# median            25.500
# strokes_16_pro     0.010
# Name: 297, dtype: float64)
# (298, readability        7.172
# emtion_entropy     0.015
# median            22.000
# strokes_16_pro     0.010
# Name: 298, dtype: float64)
# (299, readability        7.603
# emtion_entropy     0.011
# median            18.000
# strokes_16_pro     0.009
# Name: 299, dtype: float64)
# (300, readability        8.226
# emtion_entropy     0.013
# median            26.000
# strokes_16_pro     0.006
# Name: 300, dtype: float64)
# (301, readability        8.666
# emtion_entropy     0.009
# median            28.000
# strokes_16_pro     0.002
# Name: 301, dtype: float64)
# (302, readability        6.807
# emtion_entropy     0.014
# median            25.500
# strokes_16_pro     0.016
# Name: 302, dtype: float64)
# (303, readability        7.761
# emtion_entropy     0.013
# median            23.000
# strokes_16_pro     0.018
# Name: 303, dtype: float64)
# (304, readability        7.937
# emtion_entropy     0.009
# median            33.500
# strokes_16_pro     0.006
# Name: 304, dtype: float64)
# (305, readability        7.363
# emtion_entropy     0.024
# median            33.500
# strokes_16_pro     0.008
# Name: 305, dtype: float64)
# (306, readability        8.928
# emtion_entropy     0.019
# median            34.500
# strokes_16_pro     0.005
# Name: 306, dtype: float64)
# (307, readability        7.652
# emtion_entropy     0.021
# median            19.500
# strokes_16_pro     0.003
# Name: 307, dtype: float64)
# (308, readability        7.259
# emtion_entropy     0.028
# median            30.500
# strokes_16_pro     0.002
# Name: 308, dtype: float64)
# (309, readability       10.419
# emtion_entropy     0.014
# median            16.000
# strokes_16_pro     0.000
# Name: 309, dtype: float64)
# (310, readability        6.875
# emtion_entropy     0.011
# median            40.000
# strokes_16_pro     0.001
# Name: 310, dtype: float64)
# (311, readability        7.377
# emtion_entropy     0.024
# median            32.500
# strokes_16_pro     0.007
# Name: 311, dtype: float64)
# (312, readability        6.309
# emtion_entropy     0.010
# median            20.500
# strokes_16_pro     0.006
# Name: 312, dtype: float64)
# (313, readability        9.566
# emtion_entropy     0.018
# median            35.000
# strokes_16_pro     0.001
# Name: 313, dtype: float64)
# (314, readability        8.156
# emtion_entropy     0.015
# median            21.000
# strokes_16_pro     0.002
# Name: 314, dtype: float64)
# (315, readability        6.676
# emtion_entropy     0.022
# median            50.500
# strokes_16_pro     0.001
# Name: 315, dtype: float64)
# (316, readability        8.734
# emtion_entropy     0.008
# median            20.500
# strokes_16_pro     0.011
# Name: 316, dtype: float64)
# (317, readability        7.821
# emtion_entropy     0.027
# median            38.500
# strokes_16_pro     0.026
# Name: 317, dtype: float64)
# (318, readability        8.355
# emtion_entropy     0.013
# median            23.500
# strokes_16_pro     0.013
# Name: 318, dtype: float64)
# (319, readability        7.077
# emtion_entropy     0.019
# median            35.500
# strokes_16_pro     0.013
# Name: 319, dtype: float64)
# (320, readability        6.896
# emtion_entropy     0.018
# median            34.000
# strokes_16_pro     0.005
# Name: 320, dtype: float64)
# (321, readability       10.423
# emtion_entropy     0.025
# median            24.500
# strokes_16_pro     0.007
# Name: 321, dtype: float64)
# (322, readability        9.554
# emtion_entropy     0.023
# median            29.000
# strokes_16_pro     0.018
# Name: 322, dtype: float64)
# (323, readability        6.960
# emtion_entropy     0.013
# median            38.000
# strokes_16_pro     0.004
# Name: 323, dtype: float64)
# (324, readability        6.921
# emtion_entropy     0.010
# median            30.500
# strokes_16_pro     0.037
# Name: 324, dtype: float64)
# (325, readability        7.371
# emtion_entropy     0.014
# median            35.000
# strokes_16_pro     0.047
# Name: 325, dtype: float64)
# (326, readability        8.485
# emtion_entropy     0.008
# median            16.500
# strokes_16_pro     0.011
# Name: 326, dtype: float64)
# (327, readability        8.215
# emtion_entropy     0.027
# median            57.000
# strokes_16_pro     0.007
# Name: 327, dtype: float64)
# (328, readability        7.410
# emtion_entropy     0.030
# median            45.500
# strokes_16_pro     0.008
# Name: 328, dtype: float64)
# (329, readability        8.329
# emtion_entropy     0.029
# median            39.500
# strokes_16_pro     0.004
# Name: 329, dtype: float64)
# (330, readability        7.341
# emtion_entropy     0.029
# median            44.500
# strokes_16_pro     0.002
# Name: 330, dtype: float64)
# (331, readability       8.811
# emtion_entropy    0.003
# median            9.000
# strokes_16_pro    0.000
# Name: 331, dtype: float64)
# (332, readability        6.810
# emtion_entropy     0.018
# median            25.500
# strokes_16_pro     0.012
# Name: 332, dtype: float64)
# (333, readability        9.389
# emtion_entropy     0.015
# median            26.000
# strokes_16_pro     0.000
# Name: 333, dtype: float64)
# (334, readability        6.469
# emtion_entropy     0.019
# median            26.500
# strokes_16_pro     0.005
# Name: 334, dtype: float64)
# (335, readability        6.875
# emtion_entropy     0.009
# median            26.500
# strokes_16_pro     0.002
# Name: 335, dtype: float64)
# (336, readability        7.275
# emtion_entropy     0.019
# median            24.500
# strokes_16_pro     0.007
# Name: 336, dtype: float64)
# (337, readability        7.148
# emtion_entropy     0.010
# median            21.500
# strokes_16_pro     0.003
# Name: 337, dtype: float64)
# (338, readability       11.206
# emtion_entropy     0.015
# median            13.500
# strokes_16_pro     0.008
# Name: 338, dtype: float64)
# (339, readability        8.163
# emtion_entropy     0.005
# median            16.000
# strokes_16_pro     0.013
# Name: 339, dtype: float64)
# (340, readability        6.481
# emtion_entropy     0.020
# median            32.000
# strokes_16_pro     0.004
# Name: 340, dtype: float64)
# (341, readability        7.606
# emtion_entropy     0.026
# median            30.000
# strokes_16_pro     0.052
# Name: 341, dtype: float64)
# (342, readability        7.507
# emtion_entropy     0.016
# median            31.000
# strokes_16_pro     0.011
# Name: 342, dtype: float64)
# (343, readability        8.223
# emtion_entropy     0.009
# median            22.500
# strokes_16_pro     0.014
# Name: 343, dtype: float64)
# (344, readability        8.407
# emtion_entropy     0.016
# median            35.500
# strokes_16_pro     0.008
# Name: 344, dtype: float64)
# (345, readability        7.486
# emtion_entropy     0.008
# median            25.000
# strokes_16_pro     0.006
# Name: 345, dtype: float64)
# (346, readability        9.292
# emtion_entropy     0.006
# median            19.000
# strokes_16_pro     0.007
# Name: 346, dtype: float64)
# (347, readability        6.968
# emtion_entropy     0.021
# median            28.500
# strokes_16_pro     0.016
# Name: 347, dtype: float64)
# (348, readability        5.779
# emtion_entropy     0.007
# median            22.500
# strokes_16_pro     0.009
# Name: 348, dtype: float64)
# (349, readability        7.441
# emtion_entropy     0.019
# median            32.000
# strokes_16_pro     0.009
# Name: 349, dtype: float64)
# (350, readability        8.063
# emtion_entropy     0.006
# median            24.000
# strokes_16_pro     0.013
# Name: 350, dtype: float64)
# (351, readability        8.630
# emtion_entropy     0.014
# median            27.000
# strokes_16_pro     0.022
# Name: 351, dtype: float64)
# (352, readability        7.617
# emtion_entropy     0.029
# median            47.500
# strokes_16_pro     0.001
# Name: 352, dtype: float64)
# (353, readability        8.480
# emtion_entropy     0.011
# median            24.000
# strokes_16_pro     0.002
# Name: 353, dtype: float64)
# (354, readability        8.315
# emtion_entropy     0.012
# median            26.000
# strokes_16_pro     0.004
# Name: 354, dtype: float64)
# (355, readability        9.396
# emtion_entropy     0.013
# median            25.500
# strokes_16_pro     0.003
# Name: 355, dtype: float64)
# (356, readability        9.045
# emtion_entropy     0.024
# median            22.000
# strokes_16_pro     0.006
# Name: 356, dtype: float64)
# (357, readability        8.688
# emtion_entropy     0.018
# median            23.500
# strokes_16_pro     0.036
# Name: 357, dtype: float64)
# (358, readability        9.143
# emtion_entropy     0.016
# ...
# Name: 7206, dtype: float64)
# (7207, readability        5.570
# emtion_entropy     0.002
# median            16.500
# strokes_16_pro     0.004
# Name: 7207, dtype: float64)
# (7208, readability       6.276
# emtion_entropy    0.001
# median            9.500
# strokes_16_pro    0.000
# Name: 7208, dtype: float64)
# (7209, readability        6.277
# emtion_entropy     0.002
# median            12.000
# strokes_16_pro     0.000
# Name: 7209, dtype: float64)
# (7210, readability        5.757
# emtion_entropy     0.002
# median            11.000
# strokes_16_pro     0.006
# Name: 7210, dtype: float64)
# (7211, readability        5.299
# emtion_entropy     0.008
# median            17.000
# strokes_16_pro     0.000
# Name: 7211, dtype: float64)
# (7212, readability        6.096
# emtion_entropy     0.013
# median            34.500
# strokes_16_pro     0.003
# Name: 7212, dtype: float64)
# (7213, readability        6.280
# emtion_entropy     0.012
# median            31.000
# strokes_16_pro     0.013
# Name: 7213, dtype: float64)
# (7214, readability        6.157
# emtion_entropy     0.032
# median            37.500
# strokes_16_pro     0.002
# Name: 7214, dtype: float64)
# (7215, readability        5.811
# emtion_entropy     0.042
# median            41.500
# strokes_16_pro     0.001
# Name: 7215, dtype: float64)
# (7216, readability        8.268
# emtion_entropy     0.006
# median            17.000
# strokes_16_pro     0.015
# Name: 7216, dtype: float64)
# (7217, readability         5.981
# emtion_entropy      0.057
# median            136.000
# strokes_16_pro      0.005
# Name: 7217, dtype: float64)
# (7218, readability        5.707
# emtion_entropy     0.015
# median            35.500
# strokes_16_pro     0.002
# Name: 7218, dtype: float64)
# (7219, readability        5.922
# emtion_entropy     0.037
# median            28.000
# strokes_16_pro     0.006
# Name: 7219, dtype: float64)
# (7220, readability         6.318
# emtion_entropy      0.040
# median            124.000
# strokes_16_pro      0.007
# Name: 7220, dtype: float64)
# (7221, readability        6.553
# emtion_entropy     0.008
# median            27.000
# strokes_16_pro     0.000
# Name: 7221, dtype: float64)
# (7222, readability        7.405
# emtion_entropy     0.019
# median            24.500
# strokes_16_pro     0.002
# Name: 7222, dtype: float64)
# (7223, readability        5.853
# emtion_entropy     0.003
# median            17.500
# strokes_16_pro     0.000
# Name: 7223, dtype: float64)
# (7224, readability        5.259
# emtion_entropy     0.003
# median            10.000
# strokes_16_pro     0.000
# Name: 7224, dtype: float64)
# (7225, readability        5.979
# emtion_entropy     0.002
# median            22.000
# strokes_16_pro     0.000
# Name: 7225, dtype: float64)
# (7226, readability        6.149
# emtion_entropy     0.012
# median            17.000
# strokes_16_pro     0.000
# Name: 7226, dtype: float64)
# (7227, readability        6.111
# emtion_entropy     0.004
# median            27.500
# strokes_16_pro     0.008
# Name: 7227, dtype: float64)
# (7228, readability         5.746
# emtion_entropy      0.057
# median            127.000
# strokes_16_pro      0.004
# Name: 7228, dtype: float64)
# (7229, readability        7.817
# emtion_entropy     0.032
# median            19.500
# strokes_16_pro     0.000
# Name: 7229, dtype: float64)
# (7230, readability        5.976
# emtion_entropy     0.004
# median            14.500
# strokes_16_pro     0.009
# Name: 7230, dtype: float64)
# (7231, readability        6.173
# emtion_entropy     0.040
# median            73.000
# strokes_16_pro     0.013
# Name: 7231, dtype: float64)
# (7232, readability        7.457
# emtion_entropy     0.014
# median            17.500
# strokes_16_pro     0.009
# Name: 7232, dtype: float64)
# (7233, readability        6.164
# emtion_entropy     0.012
# median            24.000
# strokes_16_pro     0.019
# Name: 7233, dtype: float64)
# (7234, readability        7.244
# emtion_entropy     0.014
# median            30.000
# strokes_16_pro     0.007
# Name: 7234, dtype: float64)
# (7235, readability        5.975
# emtion_entropy     0.008
# median            23.500
# strokes_16_pro     0.006
# Name: 7235, dtype: float64)
# (7236, readability        6.798
# emtion_entropy     0.016
# median            32.500
# strokes_16_pro     0.007
# Name: 7236, dtype: float64)
# (7237, readability        7.525
# emtion_entropy     0.012
# median            22.500
# strokes_16_pro     0.005
# Name: 7237, dtype: float64)
# (7238, readability        7.492
# emtion_entropy     0.009
# median            20.000
# strokes_16_pro     0.011
# Name: 7238, dtype: float64)
# (7239, readability        7.381
# emtion_entropy     0.008
# median            26.500
# strokes_16_pro     0.004
# Name: 7239, dtype: float64)
# (7240, readability        9.102
# emtion_entropy     0.003
# median            18.000
# strokes_16_pro     0.002
# Name: 7240, dtype: float64)
# (7241, readability        9.657
# emtion_entropy     0.013
# median            20.000
# strokes_16_pro     0.002
# Name: 7241, dtype: float64)
# (7242, readability        8.842
# emtion_entropy     0.010
# median            22.000
# strokes_16_pro     0.008
# Name: 7242, dtype: float64)
# (7243, readability        6.168
# emtion_entropy     0.007
# median            13.000
# strokes_16_pro     0.000
# Name: 7243, dtype: float64)
# (7244, readability        8.401
# emtion_entropy     0.011
# median            20.500
# strokes_16_pro     0.002
# Name: 7244, dtype: float64)
# (7245, readability       7.693
# emtion_entropy    0.006
# median            8.500
# strokes_16_pro    0.012
# Name: 7245, dtype: float64)
# (7246, readability        5.787
# emtion_entropy     0.014
# median            43.000
# strokes_16_pro     0.002
# Name: 7246, dtype: float64)
# (7247, readability       6.415
# emtion_entropy    0.007
# median            9.000
# strokes_16_pro    0.000
# Name: 7247, dtype: float64)
# (7248, readability        8.608
# emtion_entropy     0.028
# median            28.000
# strokes_16_pro     0.007
# Name: 7248, dtype: float64)
# (7249, readability        7.597
# emtion_entropy     0.005
# median            24.500
# strokes_16_pro     0.002
# Name: 7249, dtype: float64)
# (7250, readability        7.289
# emtion_entropy     0.008
# median            27.500
# strokes_16_pro     0.008
# Name: 7250, dtype: float64)
# (7251, readability        7.660
# emtion_entropy     0.006
# median            23.500
# strokes_16_pro     0.006
# Name: 7251, dtype: float64)
# (7252, readability        7.458
# emtion_entropy     0.006
# median            23.500
# strokes_16_pro     0.015
# Name: 7252, dtype: float64)
# (7253, readability        7.140
# emtion_entropy     0.017
# median            24.000
# strokes_16_pro     0.002
# Name: 7253, dtype: float64)
# (7254, readability        7.850
# emtion_entropy     0.027
# median            25.000
# strokes_16_pro     0.002
# Name: 7254, dtype: float64)
# (7255, readability        8.088
# emtion_entropy     0.004
# median            19.000
# strokes_16_pro     0.008
# Name: 7255, dtype: float64)
# (7256, readability        6.831
# emtion_entropy     0.015
# median            24.000
# strokes_16_pro     0.014
# Name: 7256, dtype: float64)
# (7257, readability        6.236
# emtion_entropy     0.017
# median            24.500
# strokes_16_pro     0.003
# Name: 7257, dtype: float64)
# (7258, readability        8.288
# emtion_entropy     0.010
# median            17.000
# strokes_16_pro     0.008
# Name: 7258, dtype: float64)
# (7259, readability        7.331
# emtion_entropy     0.023
# median            29.500
# strokes_16_pro     0.032
# Name: 7259, dtype: float64)
# (7260, readability        7.692
# emtion_entropy     0.007
# median            15.000
# strokes_16_pro     0.000
# Name: 7260, dtype: float64)
# (7261, readability        6.799
# emtion_entropy     0.008
# median            23.000
# strokes_16_pro     0.023
# Name: 7261, dtype: float64)
# (7262, readability        7.020
# emtion_entropy     0.011
# median            22.500
# strokes_16_pro     0.003
# Name: 7262, dtype: float64)
# (7263, readability        7.009
# emtion_entropy     0.020
# median            23.000
# strokes_16_pro     0.002
# Name: 7263, dtype: float64)
# (7264, readability        7.797
# emtion_entropy     0.030
# median            37.500
# strokes_16_pro     0.000
# Name: 7264, dtype: float64)
# (7265, readability        9.612
# emtion_entropy     0.014
# median            32.000
# strokes_16_pro     0.006
# Name: 7265, dtype: float64)
# (7266, readability        6.879
# emtion_entropy     0.015
# median            21.000
# strokes_16_pro     0.003
# Name: 7266, dtype: float64)
# (7267, readability        4.749
# emtion_entropy     0.004
# median            18.500
# strokes_16_pro     0.016
# Name: 7267, dtype: float64)
# (7268, readability        9.902
# emtion_entropy     0.012
# median            13.000
# strokes_16_pro     0.000
# Name: 7268, dtype: float64)
# (7269, readability        5.676
# emtion_entropy     0.006
# median            40.500
# strokes_16_pro     0.009
# Name: 7269, dtype: float64)
# (7270, readability        5.833
# emtion_entropy     0.011
# median            43.500
# strokes_16_pro     0.003
# Name: 7270, dtype: float64)
# (7271, readability        6.268
# emtion_entropy     0.027
# median            51.500
# strokes_16_pro     0.005
# Name: 7271, dtype: float64)
# (7272, readability        4.599
# emtion_entropy     0.014
# median            46.500
# strokes_16_pro     0.004
# Name: 7272, dtype: float64)
# (7273, readability        5.800
# emtion_entropy     0.011
# median            67.000
# strokes_16_pro     0.010
# Name: 7273, dtype: float64)
# (7274, readability        6.069
# emtion_entropy     0.007
# median            25.500
# strokes_16_pro     0.009
# Name: 7274, dtype: float64)
# (7275, readability        6.758
# emtion_entropy     0.010
# median            40.000
# strokes_16_pro     0.001
# Name: 7275, dtype: float64)
# (7276, readability        7.674
# emtion_entropy     0.026
# median            35.500
# strokes_16_pro     0.008
# Name: 7276, dtype: float64)
# (7277, readability        5.107
# emtion_entropy     0.013
# median            46.500
# strokes_16_pro     0.004
# Name: 7277, dtype: float64)
# (7278, readability        4.889
# emtion_entropy     0.008
# median            34.500
# strokes_16_pro     0.025
# Name: 7278, dtype: float64)
# (7279, readability        6.521
# emtion_entropy     0.006
# median            34.000
# strokes_16_pro     0.008
# Name: 7279, dtype: float64)
# (7280, readability        6.012
# emtion_entropy     0.029
# median            59.500
# strokes_16_pro     0.010
# Name: 7280, dtype: float64)
# (7281, readability         5.959
# emtion_entropy      0.073
# median            212.500
# strokes_16_pro      0.017
# Name: 7281, dtype: float64)
# (7282, readability         6.132
# emtion_entropy      0.095
# median            181.000
# strokes_16_pro      0.009
# Name: 7282, dtype: float64)
# (7283, readability         6.274
# emtion_entropy      0.059
# median            150.500
# strokes_16_pro      0.012
# Name: 7283, dtype: float64)
# (7284, readability         6.079
# emtion_entropy      0.068
# median            168.500
# strokes_16_pro      0.010
# Name: 7284, dtype: float64)
# (7285, readability         5.471
# emtion_entropy      0.059
# median            163.500
# strokes_16_pro      0.007
# Name: 7285, dtype: float64)
# (7286, readability         5.792
# emtion_entropy      0.083
# median            143.000
# strokes_16_pro      0.011
# Name: 7286, dtype: float64)
# (7287, readability        5.412
# emtion_entropy     0.018
# median            63.000
# strokes_16_pro     0.009
# Name: 7287, dtype: float64)
# (7288, readability         6.074
# emtion_entropy      0.067
# median            152.000
# strokes_16_pro      0.008
# Name: 7288, dtype: float64)
# (7289, readability         6.094
# emtion_entropy      0.079
# median            181.000
# strokes_16_pro      0.015
# Name: 7289, dtype: float64)
# (7290, readability         5.784
# emtion_entropy      0.064
# median            135.000
# strokes_16_pro      0.010
# Name: 7290, dtype: float64)
# (7291, readability        6.541
# emtion_entropy     0.053
# median            51.500
# strokes_16_pro     0.012
# Name: 7291, dtype: float64)
# (7292, readability         6.519
# emtion_entropy      0.063
# median            156.000
# strokes_16_pro      0.009
# Name: 7292, dtype: float64)
# (7293, readability         5.836
# emtion_entropy      0.170
# median            441.000
# strokes_16_pro      0.015
# Name: 7293, dtype: float64)
# (7294, readability         6.699
# emtion_entropy      0.048
# median            124.000
# strokes_16_pro      0.009
# Name: 7294, dtype: float64)
# (7295, readability         6.179
# emtion_entropy      0.087
# median            145.500
# strokes_16_pro      0.007
# Name: 7295, dtype: float64)
# (7296, readability         6.420
# emtion_entropy      0.051
# median            148.500
# strokes_16_pro      0.013
# Name: 7296, dtype: float64)
# (7297, readability         5.773
# emtion_entropy      0.060
# median            187.500
# strokes_16_pro      0.019
# Name: 7297, dtype: float64)
# (7298, readability         6.378
# emtion_entropy      0.056
# median            149.500
# strokes_16_pro      0.015
# Name: 7298, dtype: float64)
# (7299, readability         6.262
# emtion_entropy      0.073
# median            168.000
# strokes_16_pro      0.022
# Name: 7299, dtype: float64)
# (7300, readability         6.049
# emtion_entropy      0.060
# median            179.500
# strokes_16_pro      0.013
# Name: 7300, dtype: float64)
# (7301, readability         6.206
# emtion_entropy      0.068
# median            152.000
# strokes_16_pro      0.005
# Name: 7301, dtype: float64)
# (7302, readability         6.678
# emtion_entropy      0.068
# median            159.000
# strokes_16_pro      0.004
# Name: 7302, dtype: float64)
# (7303, readability         6.479
# emtion_entropy      0.048
# median            180.500
# strokes_16_pro      0.024
# Name: 7303, dtype: float64)
# (7304, readability         6.408
# emtion_entropy      0.079
# median            141.500
# strokes_16_pro      0.021
# Name: 7304, dtype: float64)
# (7305, readability         6.214
# emtion_entropy      0.057
# median            173.500
# strokes_16_pro      0.009
# Name: 7305, dtype: float64)
# (7306, readability         6.026
# emtion_entropy      0.086
# median            195.000
# strokes_16_pro      0.011
# Name: 7306, dtype: float64)
# (7307, readability         6.095
# emtion_entropy      0.046
# median            180.000
# strokes_16_pro      0.016
# Name: 7307, dtype: float64)
# (7308, readability         6.464
# emtion_entropy      0.059
# median            142.500
# strokes_16_pro      0.013
# Name: 7308, dtype: float64)
# (7309, readability         5.891
# emtion_entropy      0.073
# median            164.000
# strokes_16_pro      0.015
# Name: 7309, dtype: float64)
# (7310, readability         6.529
# emtion_entropy      0.051
# median            158.000
# strokes_16_pro      0.009
# Name: 7310, dtype: float64)
# (7311, readability         5.889
# emtion_entropy      0.082
# median            199.500
# strokes_16_pro      0.009
# Name: 7311, dtype: float64)
# (7312, readability         6.330
# emtion_entropy      0.084
# median            159.000
# strokes_16_pro      0.011
# Name: 7312, dtype: float64)
# (7313, readability         6.159
# emtion_entropy      0.046
# median            159.500
# strokes_16_pro      0.013
# Name: 7313, dtype: float64)
# (7314, readability         6.002
# emtion_entropy      0.067
# median            174.500
# strokes_16_pro      0.013
# Name: 7314, dtype: float64)
# (7315, readability         6.660
# emtion_entropy      0.083
# median            166.000
# strokes_16_pro      0.015
# Name: 7315, dtype: float64)
# (7316, readability         6.189
# emtion_entropy      0.052
# median            146.500
# strokes_16_pro      0.010
# Name: 7316, dtype: float64)
# (7317, readability         6.349
# emtion_entropy      0.064
# median            166.500
# strokes_16_pro      0.019
# Name: 7317, dtype: float64)
# (7318, readability         5.521
# emtion_entropy      0.063
# median            183.000
# strokes_16_pro      0.010
# Name: 7318, dtype: float64)
# (7319, readability         5.584
# emtion_entropy      0.083
# median            184.000
# strokes_16_pro      0.003
# Name: 7319, dtype: float64)
# (7320, readability         6.662
# emtion_entropy      0.047
# median            165.500
# strokes_16_pro      0.008
# Name: 7320, dtype: float64)
# (7321, readability         5.865
# emtion_entropy      0.074
# median            196.000
# strokes_16_pro      0.026
# Name: 7321, dtype: float64)
# (7322, readability         6.060
# emtion_entropy      0.071
# median            193.500
# strokes_16_pro      0.009
# Name: 7322, dtype: float64)
# (7323, readability         6.333
# emtion_entropy      0.077
# median            160.000
# strokes_16_pro      0.010
# Name: 7323, dtype: float64)

# %%
i
# Out:
# (7323, readability         6.333
#  emtion_entropy      0.077
#  median            160.000
#  strokes_16_pro      0.010
#  Name: 7323, dtype: float64)

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set_style('white',{'font.sans-serif':['simhei','Arial']})

# %%
sns.pairplot(new_stodf)

# %%
from scipy.optimize import leastsq
import numpy as np


def main():
    # data provided
    '''x = np.array([[1, 50, 5, 200], [1, 50, 5, 400], [1, 50, 5, 600], [1, 50, 5, 800], [1, 50, 5, 1000],
                 [1, 50, 10, 200], [1, 50, 10, 400], [1, 50, 10, 600], [1, 50, 10, 800], [1, 50, 10, 1000],
                 [1, 60, 5, 200], [1, 60, 5, 400], [1, 60, 5, 600], [1, 60, 5, 800], [1, 60, 5, 1000],
                 [1, 60, 10, 200], [1, 60, 10, 400], [1, 60, 10, 600], [1, 60, 10, 800], [1, 60, 10, 1000],
                 [1, 70, 5, 200], [1, 70, 5, 400], [1, 70, 5, 600], [1, 70, 5, 800], [1, 70, 5, 1000],
                 [1, 70, 10, 200], [1, 70, 10, 400]])'''
    x = train.values
    y = test.values
    '''y = np.array([7.434, 3.011, 1.437, 0.6728, 0.00036,
               5.518, 2.556, 1.341, 0.6824, 0.0001,
               18.22, 7.344, 4.066, 1.799, 1.218,
               16.11, 9.448, 4.752, 2.245, 1.539,
               18.14, 12.88, 7.29, 3.449, 2.533,
               15.76, 16.24])'''
    # here, create lambda functions for Line fit
    # tpl is a tuple that contains the parameters of the fit
    funcLine=lambda tpl,x: np.dot(x, tpl)
    # func is going to be a placeholder for funcLine,funcQuad or whatever
    # function we would like to fit
    func = funcLine
    # ErrorFunc is the diference between the func and the y "experimental" data
    ErrorFunc = lambda tpl, x, y: func(tpl, x)-y
    #tplInitial contains the "first guess" of the parameters
    tplInitial=[1.0, 1.0, 1.0, 1.0]
    # leastsq finds the set of parameters in the tuple tpl that minimizes
    # ErrorFunc=yfit-yExperimental
    tplFinal, success = leastsq(ErrorFunc, tplInitial, args=(x, y))
    print('linear fit', tplFinal)
    print(funcLine(tplFinal, x))


if __name__ == "__main__":
   main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-08be80f508fe> in <module>()
#      37
#      38 if __name__ == "__main__":
# ---> 39    main()
#
# <ipython-input-94-08be80f508fe> in main()
#      31     # leastsq finds the set of parameters in the tuple tpl that minimizes
#      32     # ErrorFunc=yfit-yExperimental
# ---> 33     tplFinal, success = leastsq(ErrorFunc, tplInitial, args=(x, y))
#      34     print('linear fit', tplFinal)
#      35     print(funcLine(tplFinal, x))
#
# /anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     381     if not isinstance(args, tuple):
#     382         args = (args,)
# --> 383     shape, dtype = _check_func('leastsq', 'func', func, x0, args, n)
#     384     m = shape[0]
#     385     if n > m:
#
# /anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in _check_func(checker, argname, thefunc, x0, args, numinputs, output_shape)
#      25 def _check_func(checker, argname, thefunc, x0, args, numinputs,
#      26                 output_shape=None):
# ---> 27     res = atleast_1d(thefunc(*((x0[:numinputs],) + args)))
#      28     if (output_shape is not None) and (shape(res) != output_shape):
#      29         if (output_shape[0] != 1):
#
# <ipython-input-94-08be80f508fe> in <lambda>(tpl, x, y)
#      26     func = funcLine
#      27     # ErrorFunc is the diference between the func and the y "experimental" data
# ---> 28     ErrorFunc = lambda tpl, x, y: func(tpl, x)-y
#      29     #tplInitial contains the "first guess" of the parameters
#      30     tplInitial=[1.0, 1.0, 1.0, 1.0]
#
# ValueError: operands could not be broadcast together with shapes (5000,) (2000,4)

# %%
##最小二乘法
import numpy as np   ##科学计算库 
import scipy as sp   ##在numpy基础上实现的部分算法库
import matplotlib.pyplot as plt  ##绘图库
from scipy.optimize import leastsq  ##引入最小二乘法算法

'''
     设置样本数据，真实数据需要在这里处理
'''
##样本数据(Xi,Yi)，需要转换成数组(列表)形式
Xi=np.array([6.19,2.51,7.29,7.01,5.7,2.66,3.98,2.5,9.1,4.2])
Yi=np.array([5.25,2.83,6.41,6.71,5.1,4.23,5.05,1.98,10.5,6.3])

Xi = story_df[['readability']].values
Yi = story_df[['median']]            

'''
    设定拟合函数和偏差函数
    函数的形状确定过程：
    1.先画样本图像
    2.根据样本图像大致形状确定函数形式(直线、抛物线、正弦余弦等)
'''

##需要拟合的函数func :指定函数的形状
def func(p,x):
    k,b=p
    return k*x+b

##偏差函数：x,y都是列表:这里的x,y更上面的Xi,Yi中是一一对应的
def error(p,x,y):
    return func(p,x)-y

'''
    主要部分：附带部分说明
    1.leastsq函数的返回值tuple，第一个元素是求解结果，第二个是求解的代价值(个人理解)
    2.官网的原话（第二个值）：Value of the cost function at the solution
    3.实例：Para=>(array([ 0.61349535,  1.79409255]), 3)
    4.返回值元组中第一个值的数量跟需要求解的参数的数量一致
'''

#k,b的初始值，可以任意设定,经过几次试验，发现p0的值会影响cost的值：Para[1]
p0=[1,20]

#把error函数中除了p0以外的参数打包到args中(使用要求)
Para=leastsq(error,p0,args=(Xi,Yi))

#读取结果
k,b=Para[0]
print("k=",k,"b=",b)
print("cost："+str(Para[1]))
print("求解的拟合直线为:")
print("y="+str(round(k,2))+"x+"+str(round(b,2)))

'''
   绘图，看拟合效果.
   matplotlib默认不支持中文，label设置中文的话需要另行设置
   如果报错，改成英文就可以
'''

#画样本点
plt.figure(figsize=(8,6)) ##指定图像比例： 8：6
plt.scatter(Xi,Yi,color="green",label="样本数据",linewidth=2) 

#x = story_df['readability']

#画拟合直线
x=np.linspace(0,12,100) ##在0-15直接画100个连续点
y=k*x+b ##函数式
plt.plot(x,y,color="red",label="拟合直线",linewidth=2) 
plt.legend(loc='lower right') #绘制图例
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ValueError: object too deep for desired array
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-96-9be4ca736871> in <module>()
#      43
#      44 #把error函数中除了p0以外的参数打包到args中(使用要求)
# ---> 45 Para=leastsq(error,p0,args=(Xi,Yi))
#      46
#      47 #读取结果
#
# /anaconda3/lib/python3.6/site-packages/scipy/optimize/minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     392         with _MINPACK_LOCK:
#     393             retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 394                                      gtol, maxfev, epsfcn, factor, diag)
#     395     else:
#     396         if col_deriv:
#
# error: Result from function call is not a proper array of floats.

# %%
train = story_data

# %%
import numpy as np
 
def loadDataSet(fileName):
    dataMat=[]
    labelMat=[]
    fr=open(fileName)
    for line in fr.readlines():
        curLine=line.strip().split(',')
        dataMat.append(list(map(float,curLine[:-1])))
        labelMat.append(float(curLine[-1]))
    
    return dataMat,labelMat
 
def standRegress(xArr,yArr):
    xMat=np.mat(xArr)
    yMat=np.mat(yArr).T
    xTx=xMat.T*xMat
    if np.linalg.det(xTx)==0.0:
        return 'nothing'
    ws=xTx.I*(xMat.T*yMat)
    return ws

# %%
#MaxMinNormalization(x,Max,Min)
min_max_scaler = preprocessing.MinMaxScaler()

#frame=data.apply(MaxMinNormalization x:x*2)
#new_read = map(MaxMinNormalization, list(new_stodf['readability']))

# %%
X_train_minmax = min_max_scaler.transform((new_stodf[['readability']])
# Out:
#   File "<ipython-input-185-dd175551e05b>", line 1
#     X_train_minmax = min_max_scaler.transform((new_stodf[['readability']])
#                                                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
data = new_stodf[['emtion_entropy','median','strokes_16_pro',
           'property_entropy',  'strokes_entropy','importance_entropy']].dropna(axis=1).iloc[1:]
data.to_csv('prediction_train.txt',index=False)

# %%
xArr,yArr=loadDataSet('prediction_train.txt')
ws=standRegress(xArr,yArr)

# %%
ws
# Out:
# matrix([[-2.62991533e-01],
#         [ 1.04209559e-04],
#         [ 8.50443095e-01],
#         [ 2.38360759e-02],
#         [ 3.18023418e-01]])

# %%
data.head()
# Out:
#    readability  emtion_entropy  median  strokes_16_pro  property_entropy  \
# 1        6.925           0.070    49.0           0.002             0.481
# 2        6.988           0.283   228.0           0.008             0.403
# 3        8.158           0.185   113.0           0.001             0.415
# 4        6.778           0.059    42.5           0.010             0.516
# 5        6.849           0.035    29.5           0.004             0.556
#
#    importance_entropy  strokes_entropy
# 1               0.215            0.481
# 2               0.096            0.403
# 3               0.136            0.415
# 4               0.086            0.516
# 5               0.077            0.556

# %%
xArr
# Out:
# [[6.925, 0.07, 49.0, 0.002, 0.481, 0.215],
#  [6.988, 0.283, 228.0, 0.008, 0.403, 0.096],
#  [8.158, 0.185, 113.0, 0.001, 0.415, 0.136],
#  [6.778, 0.059, 42.5, 0.01, 0.516, 0.086],
#  [6.849, 0.035, 29.5, 0.004, 0.556, 0.077],
#  [6.308, 0.044, 34.5, 0.004, 0.548, 0.175],
#  [6.656, 0.131, 97.0, 0.003, 0.452, 0.176],
#  [6.621, 0.164, 111.0, 0.005, 0.43, 0.084],
#  [6.355, 0.091, 98.0, 0.006, 0.497, 0.132],
#  [7.476, 0.078, 44.5, 0.005, 0.5, 0.132],
#  [6.496, 0.115, 100.0, 0.011, 0.451, 0.126],
#  [6.162, 0.133, 116.0, 0.004, 0.429, 0.187],
#  [6.641, 0.122, 105.0, 0.003, 0.425, 0.115],
#  [7.025, 0.045, 45.0, 0.002, 0.516, 0.217],
#  [5.974, 0.251, 243.0, 0.012, 0.405, 0.121],
#  [6.786, 0.167, 114.5, 0.005, 0.424, 0.129],
#  [6.743, 0.178, 109.0, 0.005, 0.423, 0.132],
#  [6.526, 0.155, 122.5, 0.005, 0.407, 0.11],
#  [6.546, 0.043, 38.0, 0.016, 0.569, 0.222],
#  [6.994, 0.032, 48.5, 0.013, 0.547, 0.247],
#  [7.066, 0.146, 135.0, 0.005, 0.416, 0.153],
#  [7.014, 0.007, 6.5, 0.0, 0.611, 0.0],
#  [8.032, 0.005, 4.5, 0.0, 0.654, 0.0],
#  [6.214, 0.002, 9.0, 0.007, 1.0, 1.0],
#  [8.015, 0.008, 6.5, 0.0, 0.796, 0.564],
#  [6.946, 0.0, 5.5, 0.0, 0.0, 0.0],
#  [10.008, 0.003, 5.0, 0.0, 0.654, 0.0],
#  [6.929, 0.001, 6.5, 0.0, 1.0, 0.0],
#  [5.916, 0.001, 10.5, 0.007, 1.0, 0.0],
#  [7.138, 0.002, 10.0, 0.006, 1.0, 0.0],
#  [7.168, 0.0, 6.5, 0.0, 0.0, 0.0],
#  [6.95, 0.008, 8.0, 0.008, 0.593, 0.311],
#  [6.966, 0.004, 16.0, 0.026, 0.732, 0.418],
#  [6.509, 0.002, 12.5, 0.005, 1.0, 0.0],
#  [6.792, 0.008, 11.0, 0.018, 0.593, 0.311],
#  [7.941, 0.005, 7.5, 0.0, 0.654, 0.0],
#  [8.046, 0.011, 14.0, 0.004, 0.702, 0.241],
#  [5.896, 0.003, 8.0, 0.009, 0.5, 1.0],
#  [6.438, 0.003, 7.5, 0.019, 0.833, 0.0],
#  [8.521, 0.014, 11.0, 0.013, 0.675, 0.0],
#  [8.562, 0.001, 6.0, 0.0, 1.0, 0.0],
#  [7.689, 0.002, 6.0, 0.009, 1.0, 1.0],
#  [7.971, 0.006, 6.0, 0.008, 0.582, 0.355],
#  [6.541, 0.005, 8.5, 0.0, 0.639, 0.0],
#  [7.771, 0.005, 7.5, 0.0, 0.94, 0.75],
#  [6.181, 0.001, 8.5, 0.0, 1.0, 0.0],
#  [5.745, 0.003, 9.0, 0.008, 0.742, 1.0],
#  [6.04, 0.001, 6.5, 0.0, 1.0, 0.0],
#  [5.592, 0.001, 11.0, 0.0, 0.75, 0.0],
#  [7.673, 0.001, 7.0, 0.0, 1.0, 0.0],
#  [5.872, 0.004, 10.5, 0.007, 0.616, 0.0],
#  [7.143, 0.0, 5.0, 0.013, 0.0, 0.0],
#  [6.55, 0.002, 5.0, 0.0, 0.75, 1.0],
#  [6.064, 0.004, 10.0, 0.0, 0.94, 0.0],
#  [7.967, 0.012, 29.0, 0.009, 0.663, 0.159],
#  [5.688, 0.003, 11.5, 0.038, 0.742, 0.0],
#  [7.863, 0.008, 22.5, 0.012, 0.743, 0.318],
#  [11.143, 0.015, 23.5, 0.009, 0.531, 0.335],
#  [6.832, 0.0, 8.5, 0.02, 0.0, 0.0],
#  [8.581, 0.004, 7.0, 0.007, 1.0, 1.0],
#  [5.61, 0.002, 9.0, 0.008, 1.0, 1.0],
#  [7.272, 0.004, 6.0, 0.0, 0.75, 0.0],
#  [8.258, 0.012, 9.5, 0.0, 0.557, 0.0],
#  [6.341, 0.008, 14.5, 0.0, 0.732, 0.484],
#  [6.663, 0.003, 7.5, 0.0, 1.0, 0.579],
#  [8.635, 0.001, 4.0, 0.013, 1.0, 0.0],
#  [8.208, 0.016, 29.5, 0.005, 0.698, 0.335],
#  [7.169, 0.0, 5.5, 0.0, 0.0, 0.0],
#  [6.949, 0.002, 6.0, 0.0, 1.0, 0.0],
#  [7.435, 0.003, 5.5, 0.0, 0.75, 0.0],
#  [7.508, 0.0, 7.0, 0.017, 0.0, 0.0],
#  [6.944, 0.006, 7.0, 0.0, 0.819, 0.0],
#  [8.087, 0.007, 5.0, 0.011, 0.819, 0.59],
#  [6.341, 0.002, 4.5, 0.015, 1.0, 0.0],
#  [7.073, 0.008, 13.5, 0.008, 0.73, 0.251],
#  [8.091, 0.02, 30.5, 0.008, 0.631, 0.098],
#  [6.512, 0.019, 26.5, 0.009, 0.697, 0.217],
#  [6.976, 0.007, 14.0, 0.004, 0.719, 0.406],
#  [6.284, 0.004, 7.5, 0.0, 0.719, 0.0],
#  [7.307, 0.005, 6.0, 0.031, 0.719, 0.406],
#  [6.728, 0.005, 11.5, 0.011, 0.871, 0.0],
#  [7.092, 0.008, 6.0, 0.0, 0.686, 0.0],
#  [7.62, 0.003, 7.5, 0.015, 1.0, 1.0],
#  [8.001, 0.0, 7.0, 0.0, 0.0, 0.0],
#  [6.457, 0.001, 8.0, 0.0, 1.0, 0.0],
#  [6.865, 0.004, 6.0, 0.022, 0.693, 0.579],
#  [5.077, 0.002, 9.0, 0.0, 0.564, 0.0],
#  [5.123, 0.003, 8.0, 0.0, 0.75, 0.0],
#  [5.407, 0.008, 25.0, 0.006, 0.736, 0.418],
#  [10.733, 0.002, 3.5, 0.0, 1.0, 0.0],
#  [7.171, 0.003, 7.5, 0.008, 0.819, 0.0],
#  [6.9, 0.004, 8.5, 0.023, 0.742, 0.0],
#  [7.284, 0.007, 6.5, 0.0, 0.812, 0.0],
#  [7.402, 0.002, 7.5, 0.015, 1.0, 0.0],
#  [7.73, 0.002, 3.0, 0.0, 1.0, 0.0],
#  [7.368, 0.005, 5.0, 0.012, 1.0, 0.579],
#  [6.487, 0.0, 7.0, 0.02, 0.0, 0.0],
#  [6.397, 0.0, 6.0, 0.012, 0.0, 0.0],
#  [6.173, 0.001, 7.0, 0.029, 0.75, 0.0],
#  [6.206, 0.004, 12.0, 0.0, 0.802, 0.406],
#  [6.714, 0.0, 6.5, 0.041, 0.0, 0.0],
#  [6.981, 0.001, 11.0, 0.0, 1.0, 0.0],
#  [7.24, 0.004, 7.5, 0.008, 0.654, 0.0],
#  [6.408, 0.001, 8.5, 0.033, 1.0, 0.0],
#  [7.324, 0.003, 8.5, 0.007, 0.75, 1.0],
#  [6.126, 0.005, 9.5, 0.0, 0.797, 0.418],
#  [7.203, 0.012, 29.0, 0.008, 0.648, 0.348],
#  [7.78, 0.001, 7.5, 0.03, 1.0, 0.0],
#  [8.12, 0.0, 7.5, 0.0, 0.0, 0.0],
#  [9.187, 0.001, 6.0, 0.0, 0.75, 1.0],
#  [5.906, 0.005, 5.5, 0.039, 0.7, 0.311],
#  [6.129, 0.011, 18.5, 0.004, 0.728, 0.181],
#  [6.739, 0.004, 9.0, 0.007, 1.0, 0.0],
#  [7.486, 0.008, 25.0, 0.006, 0.775, 0.0],
#  [6.093, 0.003, 11.5, 0.006, 0.917, 0.0],
#  [7.645, 0.02, 25.5, 0.008, 0.599, 0.182],
#  [8.452, 0.0, 3.0, 0.02, 0.0, 0.0],
#  [7.498, 0.002, 7.5, 0.008, 0.75, 1.0],
#  [7.624, 0.017, 28.5, 0.004, 0.689, 0.244],
#  [7.243, 0.002, 9.5, 0.006, 0.871, 1.0],
#  [8.235, 0.003, 6.0, 0.0, 1.0, 0.0],
#  [7.73, 0.003, 7.5, 0.0, 0.564, 0.0],
#  [5.904, 0.001, 10.0, 0.038, 1.0, 0.0],
#  [8.111, 0.009, 8.0, 0.0, 0.672, 0.613],
#  [7.693, 0.025, 44.0, 0.024, 0.676, 0.326],
#  [5.175, 0.01, 24.0, 0.005, 0.682, 0.469],
#  [8.39, 0.012, 26.5, 0.024, 0.613, 0.211],
#  [8.612, 0.007, 13.5, 0.017, 0.75, 0.0],
#  [7.622, 0.004, 4.0, 0.0, 0.742, 0.0],
#  [6.316, 0.0, 6.5, 0.011, 0.0, 0.0],
#  [8.768, 0.002, 4.5, 0.034, 1.0, 0.0],
#  [8.224, 0.005, 5.0, 0.033, 0.639, 0.0],
#  [7.032, 0.002, 5.5, 0.024, 1.0, 0.0],
#  [6.917, 0.012, 14.5, 0.0, 0.65, 0.141],
#  [9.156, 0.001, 8.0, 0.012, 1.0, 0.0],
#  [6.999, 0.004, 9.5, 0.0, 0.802, 0.0],
#  [6.024, 0.009, 28.0, 0.004, 0.608, 0.0],
#  [5.409, 0.011, 17.5, 0.022, 0.533, 0.0],
#  [8.284, 0.012, 18.5, 0.014, 0.412, 0.307],
#  [7.199, 0.019, 24.5, 0.012, 0.556, 0.185],
#  [8.169, 0.023, 24.5, 0.0, 0.409, 0.227],
#  [6.056, 0.024, 25.5, 0.019, 0.611, 0.371],
#  [8.17, 0.018, 27.5, 0.003, 0.729, 0.35],
#  [4.871, 0.003, 11.0, 0.021, 0.898, 0.579],
#  [4.901, 0.021, 58.0, 0.005, 0.608, 0.224],
#  [5.015, 0.002, 12.0, 0.006, 0.75, 1.0],
#  [7.608, 0.003, 6.5, 0.0, 0.654, 0.406],
#  [5.823, 0.0, 9.5, 0.016, 0.0, 0.0],
#  [7.055, 0.0, 6.5, 0.019, 0.0, 0.0],
#  [8.625, 0.003, 9.5, 0.0, 0.693, 0.0],
#  [6.609, 0.002, 11.5, 0.006, 0.75, 1.0],
#  [6.391, 0.01, 11.0, 0.0, 0.634, 0.311],
#  [8.644, 0.013, 8.5, 0.012, 0.703, 0.127],
#  [7.181, 0.008, 29.0, 0.008, 0.652, 0.433],
#  [7.998, 0.02, 25.5, 0.008, 0.59, 0.074],
#  [6.814, 0.009, 21.5, 0.005, 0.686, 0.409],
#  [6.881, 0.011, 36.5, 0.001, 0.642, 0.348],
#  [5.58, 0.019, 30.0, 0.035, 0.68, 0.167],
#  [7.937, 0.011, 13.5, 0.011, 0.676, 0.241],
#  [8.221, 0.018, 33.0, 0.019, 0.663, 0.181],
#  [7.173, 0.006, 7.5, 0.007, 0.798, 0.355],
#  [7.468, 0.002, 5.5, 0.0, 0.871, 0.0],
#  [6.023, 0.0, 6.5, 0.0, 0.0, 0.0],
#  [5.483, 0.01, 11.5, 0.0, 0.729, 0.241],
#  [7.024, 0.006, 16.5, 0.0, 0.94, 0.59],
#  [6.975, 0.003, 8.0, 0.015, 0.742, 0.0],
#  [6.529, 0.003, 8.5, 0.008, 1.0, 1.0],
#  [5.658, 0.003, 6.5, 0.013, 0.742, 0.579],
#  [6.461, 0.012, 26.5, 0.013, 0.74, 0.244],
#  [7.505, 0.004, 7.5, 0.046, 0.742, 0.579],
#  [8.28, 0.007, 19.5, 0.0, 0.732, 0.0],
#  [8.438, 0.004, 4.0, 0.0, 0.871, 0.579],
#  [7.93, 0.013, 21.0, 0.012, 0.675, 0.386],
#  [6.307, 0.002, 13.0, 0.016, 1.0, 1.0],
#  [5.666, 0.005, 11.5, 0.0, 1.0, 0.579],
#  [6.177, 0.001, 10.5, 0.013, 1.0, 0.0],
#  [6.228, 0.004, 14.0, 0.01, 1.0, 0.579],
#  [8.465, 0.01, 22.5, 0.006, 0.726, 0.469],
#  [6.496, 0.003, 12.0, 0.006, 0.75, 0.418],
#  [8.343, 0.0, 8.5, 0.0, 0.0, 0.0],
#  [6.859, 0.005, 7.5, 0.0, 0.833, 0.5],
#  [7.196, 0.002, 11.0, 0.0, 0.693, 0.0],
#  [6.087, 0.001, 7.0, 0.0, 1.0, 0.0],
#  [5.974, 0.002, 9.5, 0.0, 1.0, 0.0],
#  [7.564, 0.001, 8.0, 0.0, 1.0, 0.0],
#  [8.483, 0.004, 7.0, 0.029, 0.833, 0.406],
#  [7.959, 0.008, 8.0, 0.014, 0.729, 0.409],
#  [7.304, 0.003, 9.5, 0.011, 0.742, 0.0],
#  [6.958, 0.002, 7.0, 0.009, 0.406, 0.0],
#  [7.4, 0.001, 4.0, 0.0, 0.75, 0.0],
#  [7.026, 0.004, 6.0, 0.0, 1.0, 0.0],
#  [7.508, 0.007, 8.0, 0.0, 0.62, 0.484],
#  [6.683, 0.001, 7.5, 0.0, 1.0, 0.0],
#  [9.452, 0.002, 3.5, 0.0, 0.5, 0.0],
#  [8.035, 0.006, 9.5, 0.006, 0.735, 0.59],
#  [4.916, 0.011, 29.0, 0.011, 0.77, 0.554],
#  [7.89, 0.003, 10.5, 0.016, 0.433, 0.0],
#  [7.009, 0.006, 8.5, 0.007, 0.819, 0.418],
#  [7.049, 0.005, 14.0, 0.004, 0.861, 0.0],
#  [8.596, 0.003, 5.5, 0.0, 1.0, 1.0],
#  [8.676, 0.003, 3.5, 0.032, 0.871, 0.579],
#  [8.297, 0.008, 13.5, 0.0, 0.686, 0.491],
#  [6.936, 0.008, 6.0, 0.0, 0.798, 0.251],
#  [7.377, 0.013, 24.5, 0.006, 0.644, 0.273],
#  [7.986, 0.003, 11.0, 0.0, 0.75, 0.0],
#  [6.342, 0.007, 7.0, 0.0, 0.498, 0.5],
#  ...]

# %%
ws

# %%
len(data)
# Out:
# 7315

# %%
len(xArr)
# Out:
# 7315

# %%
len(yArr)
# Out:
# 7315
